# %%
import pandas as pd
import numpy as np
from statsmodels.formula.api import ols as sm_ols
from statsmodels.iolib.summary2 import summary_col
import seaborn as sns

# %%
# load the data for startups
startups = (pd.read_csv('Startup Data/startup_raw.csv'))
# get rid of commas so they can be converted to integers
for column in startups.columns:
    # Check if the column contains string data type
    if startups[column].dtype == 'object':
        # Replace commas with an empty string in the column
        startups[column] = startups[column].str.replace(',', '')

startups
# Out:
#     Year Ended Surviving Establishments Total Employment of Survivors  \
# 0       2015.0                   677876                       3011469
# 1       2016.0                   539701                       3073279
# 2       2017.0                   468293                       3081916
# 3       2018.0                   416438                       3075769
# 4       2019.0                   375833                       3043285
# ..         ...                      ...                           ...
# 62         NaN                      NaN                           NaN
# 63         NaN                      NaN                           NaN
# 64         NaN                      NaN                           NaN
# 65         NaN                      NaN                           NaN
# 66         NaN                      NaN                           NaN
#
#     Survival Rates Since Birth (%)  Labor Force Participation Rate (%)
# 0                            100.0                                 4.4
# 1                             79.6                                 5.7
# 2                             69.1                                 6.6
# 3                             61.4                                 7.4
# 4                             55.4                                 8.1
# ..                             ...                                 ...
# 62                             NaN                                 NaN
# 63                             NaN                                 NaN
# 64                             NaN                                 NaN
# 65                             NaN                                 NaN
# 66                             NaN                                 NaN
#
# [67 rows x 5 columns]

# %%
# filter to include only the years that have a 100% survival rate to show how many startups were made that year
startups_started = startups[startups['Survival Rates Since Birth (%)'] == 100]

# making the year column an integer for merge
startups_started = startups_started.rename(columns={'Year Ended' : 'year'})
startups_started = startups_started.rename(columns={'Surviving Establishments' : 'Surviving_Establishments'})
startups_started['Surviving_Establishments'] = startups_started['Surviving_Establishments'].astype(float)                                                          
startups_started
# Out:
#       year  Surviving_Establishments Total Employment of Survivors  \
# 0   2015.0                  677876.0                       3011469
# 9   2016.0                  732856.0                       3130736
# 17  2017.0                  733286.0                       3111021
# 24  2018.0                  733721.0                       3090584
# 29  2019.0                  770523.0                       3116850
# 34  2020.0                  767573.0                       3063425
# 38  2021.0                  839297.0                       2985309
# 41  2022.0                 1065228.0                       3697739
# 43  2023.0                 1054052.0                       3710694
#
#     Survival Rates Since Birth (%)  Labor Force Participation Rate (%)
# 0                            100.0                                 4.4
# 9                            100.0                                 4.3
# 17                           100.0                                 4.2
# 24                           100.0                                 4.2
# 29                           100.0                                 4.0
# 34                           100.0                                 4.0
# 38                           100.0                                 3.6
# 41                           100.0                                 3.5
# 43                           100.0                                 3.5

# %%
# Filtering the startups to only have the year and number of establishments

selected_columns = ['year', 'Surviving_Establishments']
startups_numbers  = startups_started[selected_columns]
startups_numbers.to_csv('Startup Data/startup_numbers.csv', index=False)

# %%
# Load work from home dataset

WFH_Data = pd.read_csv('Work From Home Data/WFH 1965-present.csv')
#WFH_Data.head(50)
WFH_Data = WFH_Data.drop(columns = ['License', 'Citation'])

# %%
# converting the year into a format that can be merged on
WFH_Data['date'] = pd.to_datetime(WFH_Data['date'])
WFH_Data['year'] = WFH_Data['date'].dt.strftime('%Y')
WFH_Data.tail(55)
# Out:
#          date  WFH_share Source_historical_series  fullremote_hist  \
# 14 2011-01-01        4.6                     ATUS              3.0
# 15 2012-01-01        5.7                     ATUS              3.1
# 16 2013-01-01        5.4                     ATUS              3.2
# 17 2014-01-01        6.4                     ATUS              3.3
# 18 2015-01-01        6.8                     ATUS              3.5
# 19 2016-01-01        5.9                     ATUS              3.9
# 20 2017-01-01        6.9                     ATUS              4.1
# 21 2018-01-01        5.3                     ATUS              4.2
# 22 2019-01-01        7.2                     ATUS              4.7
# 23 2020-05-01       61.5                     SWAA              NaN
# 24 2020-07-01       51.0                     SWAA              NaN
# 25 2020-08-01       48.3                     SWAA              NaN
# 26 2020-09-01       44.3                     SWAA              NaN
# 27 2020-10-01       43.3                     SWAA              NaN
# 28 2020-11-01       38.8                     SWAA              NaN
# 29 2020-12-01       37.0                     SWAA              NaN
# 30 2021-01-01       36.8                     SWAA              NaN
# 31 2021-02-01       34.1                     SWAA              NaN
# 32 2021-03-01       34.6                     SWAA              NaN
# 33 2021-04-01       34.9                     SWAA              NaN
# 34 2021-05-01       32.9                     SWAA              NaN
# 35 2021-06-01       32.8                     SWAA              NaN
# 36 2021-07-01       33.6                     SWAA              NaN
# 37 2021-08-01       32.0                     SWAA              NaN
# 38 2021-09-01       32.5                     SWAA              NaN
# 39 2021-10-01       32.2                     SWAA              NaN
# 40 2021-11-01       33.1                     SWAA              NaN
# 41 2021-12-01       33.3                     SWAA              NaN
# 42 2022-01-01       32.4                     SWAA              NaN
# 43 2022-02-01       31.2                     SWAA              NaN
# 44 2022-03-01       31.1                     SWAA              NaN
# 45 2022-04-01       29.6                     SWAA              NaN
# 46 2022-05-01       31.5                     SWAA              NaN
# 47 2022-06-01       31.6                     SWAA              NaN
# 48 2022-07-01       30.6                     SWAA              NaN
# 49 2022-08-01       29.5                     SWAA              NaN
# 50 2022-09-01       29.1                     SWAA              NaN
# 51 2022-10-01       29.4                     SWAA              NaN
# 52 2022-11-01       28.9                     SWAA              NaN
# 53 2022-12-01       29.3                     SWAA              NaN
# 54 2023-01-01       27.2                     SWAA              NaN
# 55 2023-02-01       27.7                     SWAA              NaN
# 56 2023-03-01       28.7                     SWAA              NaN
# 57 2023-04-01       28.4                     SWAA              NaN
# 58 2023-05-01       28.2                     SWAA              NaN
# 59 2023-06-01       28.1                     SWAA              NaN
# 60 2023-07-01       30.7                     SWAA              NaN
# 61 2023-08-01       30.7                     SWAA              NaN
# 62 2023-09-01       29.4                     SWAA              NaN
# 63 2023-10-01       28.0                     SWAA              NaN
# 64 2023-11-01       28.6                     SWAA              NaN
# 65 2023-12-01       29.5                     SWAA              NaN
# 66 2024-01-01       28.8                     SWAA              NaN
# 67 2024-02-01       27.8                     SWAA              NaN
# 68 2024-03-01       27.5                     SWAA              NaN
#
#    Source_fullremote_hist                                              Notes  \
# 14                    ACS                                                NaN
# 15                    ACS                                                NaN
# 16                    ACS                                                NaN
# 17                    ACS                                                NaN
# 18                    ACS                                                NaN
# 19                    ACS                                                NaN
# 20                    ACS                                                NaN
# 21                    ACS                                                NaN
# 22                    ACS                                                NaN
# 23                    NaN                                                NaN
# 24                    NaN                                                NaN
# 25                    NaN                                                NaN
# 26                    NaN                                                NaN
# 27                    NaN                                                NaN
# 28                    NaN                                                NaN
# 29                    NaN                                                NaN
# 30                    NaN                                                NaN
# 31                    NaN                                                NaN
# 32                    NaN                                                NaN
# 33                    NaN                                                NaN
# 34                    NaN                                                NaN
# 35                    NaN                                                NaN
# 36                    NaN                                                NaN
# 37                    NaN                                                NaN
# 38                    NaN                                                NaN
# 39                    NaN                                                NaN
# 40                    NaN                                                NaN
# 41                    NaN                                                NaN
# 42                    NaN                                                NaN
# 43                    NaN                                                NaN
# 44                    NaN                                                NaN
# 45                    NaN                                                NaN
# 46                    NaN                                                NaN
# 47                    NaN                                                NaN
# 48                    NaN                                                NaN
# 49                    NaN                                                NaN
# 50                    NaN                                                NaN
# 51                    NaN                                                NaN
# 52                    NaN                                                NaN
# 53                    NaN                                                NaN
# 54                    NaN                                                NaN
# 55                    NaN                                                NaN
# 56                    NaN                                                NaN
# 57                    NaN                                                NaN
# 58                    NaN                                                NaN
# 59                    NaN                                                NaN
# 60                    NaN                                                NaN
# 61                    NaN                                                NaN
# 62                    NaN  The September 2023 SWAA estimate averages the ...
# 63                    NaN                                                NaN
# 64                    NaN                                                NaN
# 65                    NaN                                                NaN
# 66                    NaN                                                NaN
# 67                    NaN                                                NaN
# 68                    NaN                                                NaN
#
#     year
# 14  2011
# 15  2012
# 16  2013
# 17  2014
# 18  2015
# 19  2016
# 20  2017
# 21  2018
# 22  2019
# 23  2020
# 24  2020
# 25  2020
# 26  2020
# 27  2020
# 28  2020
# 29  2020
# 30  2021
# 31  2021
# 32  2021
# 33  2021
# 34  2021
# 35  2021
# 36  2021
# 37  2021
# 38  2021
# 39  2021
# 40  2021
# 41  2021
# 42  2022
# 43  2022
# 44  2022
# 45  2022
# 46  2022
# 47  2022
# 48  2022
# 49  2022
# 50  2022
# 51  2022
# 52  2022
# 53  2022
# 54  2023
# 55  2023
# 56  2023
# 57  2023
# 58  2023
# 59  2023
# 60  2023
# 61  2023
# 62  2023
# 63  2023
# 64  2023
# 65  2023
# 66  2024
# 67  2024
# 68  2024

# %%
# only need years 2015 onward
filtered_WFH = WFH_Data.iloc[18:23]
filtered_WFH
# Out:
#          date  WFH_share Source_historical_series  fullremote_hist  \
# 18 2015-01-01        6.8                     ATUS              3.5
# 19 2016-01-01        5.9                     ATUS              3.9
# 20 2017-01-01        6.9                     ATUS              4.1
# 21 2018-01-01        5.3                     ATUS              4.2
# 22 2019-01-01        7.2                     ATUS              4.7
#
#    Source_fullremote_hist Notes  year
# 18                    ACS   NaN  2015
# 19                    ACS   NaN  2016
# 20                    ACS   NaN  2017
# 21                    ACS   NaN  2018
# 22                    ACS   NaN  2019

# %%
WFH_Data.loc[len(WFH_Data.index)] = ['NaN', "%.1f"%WFH_Data.loc[WFH_Data['year']=='2020', 'WFH_share'].mean(), 'NaN', 'NaN', 'NaN', 'NaN', 2020 ] 
WFH_Data.loc[len(WFH_Data.index)] = ['NaN', "%.1f"%WFH_Data.loc[WFH_Data['year']=='2021', 'WFH_share'].mean(), 'NaN', 'NaN', 'NaN', 'NaN', 2021 ] 
WFH_Data.loc[len(WFH_Data.index)] = ['NaN', "%.1f"%WFH_Data.loc[WFH_Data['year']=='2022', 'WFH_share'].mean(), 'NaN', 'NaN', 'NaN', 'NaN', 2022 ] 
WFH_Data.loc[len(WFH_Data.index)] = ['NaN', "%.1f"%WFH_Data.loc[WFH_Data['year']=='2023', 'WFH_share'].mean(), 'NaN', 'NaN', 'NaN', 'NaN', 2023 ] 
WFH_Data.loc[len(WFH_Data.index)] = ['NaN', "%.1f"%WFH_Data.loc[WFH_Data['year']=='2024', 'WFH_share'].mean(), 'NaN', 'NaN', 'NaN', 'NaN', 2024 ] 
WFH_Data
# Out:
#                    date WFH_share Source_historical_series fullremote_hist  \
# 0   1965-01-01 00:00:00       0.4                    AHTUS             NaN
# 1   1975-01-01 00:00:00       0.6                    AHTUS             NaN
# 2   1985-01-01 00:00:00       4.8                    AHTUS             NaN
# 3   1993-01-01 00:00:00       2.5                    AHTUS             NaN
# 4   1995-01-01 00:00:00       2.2                    AHTUS             NaN
# ..                  ...       ...                      ...             ...
# 69                  NaN      46.3                      NaN             NaN
# 70                  NaN      33.6                      NaN             NaN
# 71                  NaN      30.3                      NaN             NaN
# 72                  NaN      28.8                      NaN             NaN
# 73                  NaN      28.0                      NaN             NaN
#
#    Source_fullremote_hist Notes  year
# 0                     NaN   NaN  1965
# 1                     NaN   NaN  1975
# 2                     NaN   NaN  1985
# 3                     NaN   NaN  1993
# 4                     NaN   NaN  1995
# ..                    ...   ...   ...
# 69                    NaN   NaN  2020
# 70                    NaN   NaN  2021
# 71                    NaN   NaN  2022
# 72                    NaN   NaN  2023
# 73                    NaN   NaN  2024
#
# [74 rows x 7 columns]

# %%
WFH_Data.tail(10)
# Out:
#                    date WFH_share Source_historical_series fullremote_hist  \
# 64  2023-11-01 00:00:00      28.6                     SWAA             NaN
# 65  2023-12-01 00:00:00      29.5                     SWAA             NaN
# 66  2024-01-01 00:00:00      28.8                     SWAA             NaN
# 67  2024-02-01 00:00:00      27.8                     SWAA             NaN
# 68  2024-03-01 00:00:00      27.5                     SWAA             NaN
# 69                  NaN      46.3                      NaN             NaN
# 70                  NaN      33.6                      NaN             NaN
# 71                  NaN      30.3                      NaN             NaN
# 72                  NaN      28.8                      NaN             NaN
# 73                  NaN      28.0                      NaN             NaN
#
#    Source_fullremote_hist Notes  year
# 64                    NaN   NaN  2023
# 65                    NaN   NaN  2023
# 66                    NaN   NaN  2024
# 67                    NaN   NaN  2024
# 68                    NaN   NaN  2024
# 69                    NaN   NaN  2020
# 70                    NaN   NaN  2021
# 71                    NaN   NaN  2022
# 72                    NaN   NaN  2023
# 73                    NaN   NaN  2024

# %%
filtered_WFH = filtered_WFH.reset_index()

# %%
filtered_WFH = pd.concat([filtered_WFH, WFH_Data.loc[WFH_Data['year'] == 2020]])
filtered_WFH = pd.concat([filtered_WFH, WFH_Data.loc[WFH_Data['year'] == 2021]])
filtered_WFH = pd.concat([filtered_WFH, WFH_Data.loc[WFH_Data['year'] == 2022]])
filtered_WFH = pd.concat([filtered_WFH, WFH_Data.loc[WFH_Data['year'] == 2023]])
# filtered_WFH = pd.concat([filtered_WFH, WFH_Data.loc[WFH_Data['year'] == 2024]])
filtered_WFH = filtered_WFH.drop_duplicates()
filtered_WFH
# Out:
#     index                 date WFH_share Source_historical_series  \
# 0    18.0  2015-01-01 00:00:00       6.8                     ATUS
# 1    19.0  2016-01-01 00:00:00       5.9                     ATUS
# 2    20.0  2017-01-01 00:00:00       6.9                     ATUS
# 3    21.0  2018-01-01 00:00:00       5.3                     ATUS
# 4    22.0  2019-01-01 00:00:00       7.2                     ATUS
# 69    NaN                  NaN      46.3                      NaN
# 70    NaN                  NaN      33.6                      NaN
# 71    NaN                  NaN      30.3                      NaN
# 72    NaN                  NaN      28.8                      NaN
#
#    fullremote_hist Source_fullremote_hist Notes  year
# 0              3.5                    ACS   NaN  2015
# 1              3.9                    ACS   NaN  2016
# 2              4.1                    ACS   NaN  2017
# 3              4.2                    ACS   NaN  2018
# 4              4.7                    ACS   NaN  2019
# 69             NaN                    NaN   NaN  2020
# 70             NaN                    NaN   NaN  2021
# 71             NaN                    NaN   NaN  2022
# 72             NaN                    NaN   NaN  2023

# %%
filtered_WFH.dtypes
# Out:
# index                       float64
# date                         object
# WFH_share                    object
# Source_historical_series     object
# fullremote_hist              object
# Source_fullremote_hist       object
# Notes                        object
# year                         object
# dtype: object

# %%
filtered_WFH['year'] = filtered_WFH['year'].astype(float)
filtered_WFH['WFH_share'] = filtered_WFH['WFH_share'].astype(float)

# %%
filtered_WFH.to_csv('Work From Home Data/cleaned_WFH.csv',index=False)

# %%
# Merge our Datasets

wfh_startups = pd.merge(filtered_WFH,
                        startups_numbers,
                        on = ['year'],
                        how = 'left',
                        validate = '1:1')
wfh_startups
# Out:
#    index                 date  WFH_share Source_historical_series  \
# 0   18.0  2015-01-01 00:00:00        6.8                     ATUS
# 1   19.0  2016-01-01 00:00:00        5.9                     ATUS
# 2   20.0  2017-01-01 00:00:00        6.9                     ATUS
# 3   21.0  2018-01-01 00:00:00        5.3                     ATUS
# 4   22.0  2019-01-01 00:00:00        7.2                     ATUS
# 5    NaN                  NaN       46.3                      NaN
# 6    NaN                  NaN       33.6                      NaN
# 7    NaN                  NaN       30.3                      NaN
# 8    NaN                  NaN       28.8                      NaN
#
#   fullremote_hist Source_fullremote_hist Notes    year  \
# 0             3.5                    ACS   NaN  2015.0
# 1             3.9                    ACS   NaN  2016.0
# 2             4.1                    ACS   NaN  2017.0
# 3             4.2                    ACS   NaN  2018.0
# 4             4.7                    ACS   NaN  2019.0
# 5             NaN                    NaN   NaN  2020.0
# 6             NaN                    NaN   NaN  2021.0
# 7             NaN                    NaN   NaN  2022.0
# 8             NaN                    NaN   NaN  2023.0
#
#    Surviving_Establishments
# 0                  677876.0
# 1                  732856.0
# 2                  733286.0
# 3                  733721.0
# 4                  770523.0
# 5                  767573.0
# 6                  839297.0
# 7                 1065228.0
# 8                 1054052.0

# %%
wfh_startups.dtypes
# Out:
# index                       float64
# date                         object
# WFH_share                   float64
# Source_historical_series     object
# fullremote_hist              object
# Source_fullremote_hist       object
# Notes                        object
# year                        float64
# Surviving_Establishments    float64
# dtype: object

# %%
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col  # Importing summary_col function
# regression model to show the relationship between the WFH share of the workforce and the number of startups created

# Run OLS
m1 = sm.OLS.from_formula('Surviving_Establishments ~ WFH_share', data=wfh_startups).fit()
m2 = sm.OLS.from_formula('Surviving_Establishments ~ np.log(WFH_share)', data=wfh_startups).fit()  # Use np.log for log transformation
m3 = sm.OLS.from_formula('np.log(Surviving_Establishments) ~ WFH_share', data=wfh_startups).fit()  # Log transform dependent variable

# Print out multiple regression results at once
table = summary_col(results=[m1, m2, m3],
                    float_format='%0.2f',
                    stars=True,
                    model_names=['m1', 'm2', 'm3'],
                    info_dict=None)  # You can pass additional information here if needed

print(table)
# Out:
# ====================================================
#                        m1           m2         m3
# ----------------------------------------------------
# Intercept         726959.06*** 550347.72*** 13.49***
#                   (69964.78)   (124714.63)  (0.08)
# WFH_share         4861.37                   0.01
#                   (2902.69)                 (0.00)
# np.log(WFH_share)              103533.89*
#                                (45633.30)
# R-squared         0.29         0.42         0.31
# R-squared Adj.    0.18         0.34         0.21
# ====================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
lineplot1 = sns.lineplot(data = wfh_startups,
             x='year',y='Surviving_Establishments') #style='gsector'

# %%
lineplot2 = sns.lineplot(data = wfh_startups,
             x='year',y='WFH_share') #style='gsector'

# %%
#lineplot3 = sns.lineplot(data = wfh_startups,
 #            x='log_wfh%',y='startups',hue='high_leverage') #style='gsector'

# %% [markdown]
# Industries focused on
# - utilities (NAICS22)
# - Finance and Insurance (NAICS52)
# - Wholesale trade (NAICS42)
# - Transportation and Warehousing (NAICSTW)
# - Real Estate (NAICS53)
# - Arts and Entertainment (NAICS71)

# %%
# Now finding Monthly Startup development by industry
# load datasets
startup_ind =  (pd.read_csv('Startup Data/Industry/bfs_monthly.csv'))
# Out:
# C:\Users\keith\AppData\Local\Temp\ipykernel_41144\1077236181.py:3: DtypeWarning: Columns (5,6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   startup_ind =  (pd.read_csv('Startup Data/Industry/bfs_monthly.csv'))

# %%
startup_ind= startup_ind.sort_values(by='year')

# Reset the index after sorting
startup_ind.reset_index(drop=True, inplace=True)
startup_ind
# Out:
#       sa naics_sector    series geo  year     jan     feb     mar  apr  may  \
# 0      U        TOTAL  BF_DUR8Q  WY  2004     NaN     NaN     NaN  NaN  NaN
# 1      U        TOTAL    BA_WBA  MI  2004     NaN     NaN     NaN  NaN  NaN
# 2      A        TOTAL    BA_WBA  MI  2004     NaN     NaN     NaN  NaN  NaN
# 3      U        TOTAL    BA_WBA  MN  2004     NaN     NaN     NaN  NaN  NaN
# 4      A        TOTAL    BA_WBA  MN  2004     NaN     NaN     NaN  NaN  NaN
# ...   ..          ...       ...  ..   ...     ...     ...     ...  ...  ...
# 33055  A        TOTAL  BF_PBF8Q  AK  2024      86      75      89  NaN  NaN
# 33056  U        TOTAL  BF_PBF8Q  AZ  2024    1198     825     801  NaN  NaN
# 33057  A        TOTAL  BF_PBF8Q  AZ  2024     845     831     826  NaN  NaN
# 33058  U        TOTAL  BF_PBF8Q  WE  2024   15800   11072   11234  NaN  NaN
# 33059  U        TOTAL     BA_BA  US  2024  574930  455499  467910  NaN  NaN
#
#        jun   jul   aug   sep   oct   nov   dec
# 0      NaN  0.85  0.90  1.43  1.09  0.89  1.51
# 1      NaN  1820  1883  1792  2104  1802  2405
# 2      NaN  1795  2170  2209  1967  2135  2054
# 3      NaN  1038  1015   864  1278   895  1101
# 4      NaN  1058  1220  1139  1307  1159   995
# ...    ...   ...   ...   ...   ...   ...   ...
# 33055  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 33056  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 33057  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 33058  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 33059  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [33060 rows x 17 columns]

# %%
# replacing the names of the naics_sector to more cleanly describe our industries
# Define a dictionary mapping NAICS codes to the corresponding sectors
naics_mapping = {
    'NAICS22': 'Utilities',
    'NAICS52': 'Finance and Insurance',
    'NAICS42': 'Wholesale Trade',
    'NAICSTW': 'Transportation and Warehousing',
    'NAICS53': 'Real Estate',
    'NAICS71': 'Arts and Entertainment'
}

# Replace values in the 'naics_sector' column using the mapping
startup_ind['naics_sector'] = startup_ind['naics_sector'].replace(naics_mapping)

# %%
# List of values to keep in the 'naics_sector' column
valid_values = ['Utilities', 'Finance and Insurance', 'Wholesale Trade',
                'Transportation and Warehousing', 'Real Estate', 'Arts and Entertainment']

# Filter the DataFrame to keep only rows with valid values in 'naics_sector' and in series
startup_ind_filtered = startup_ind[startup_ind['naics_sector'].isin(valid_values)]

# We only want values in the years 2021 to 2024, then we want everything aside from industry and year to be consistent for merging
startup_ind_filtered = startup_ind_filtered[(startup_ind_filtered['year'] >= 2021) & (startup_ind_filtered['year'] <= 2024)]
startup_ind_filtered = startup_ind_filtered[(startup_ind_filtered['sa'] == 'A') & (startup_ind_filtered['series'] == 'BA_BA') & (startup_ind_filtered['geo'] == 'US')]

# %%
startup_ind_filtered.rename(columns={'naics_sector': 'sector'}, inplace=True)

# %%
startup_ind_filtered
# Out:
#       sa                          sector series geo  year    jan    feb  \
# 28581  A                       Utilities  BA_BA  US  2021    377    393
# 28584  A                 Wholesale Trade  BA_BA  US  2021  12575  11094
# 28586  A  Transportation and Warehousing  BA_BA  US  2021  40285  33911
# 28588  A           Finance and Insurance  BA_BA  US  2021  22445  21083
# 28589  A                     Real Estate  BA_BA  US  2021  24827  22073
# 28633  A          Arts and Entertainment  BA_BA  US  2021  13204  11486
# 29798  A                       Utilities  BA_BA  US  2022    419    470
# 29801  A                 Wholesale Trade  BA_BA  US  2022   9655   9273
# 29803  A  Transportation and Warehousing  BA_BA  US  2022  38625  37345
# 29805  A           Finance and Insurance  BA_BA  US  2022  20186  19529
# 29806  A                     Real Estate  BA_BA  US  2022  25218  24449
# 29850  A          Arts and Entertainment  BA_BA  US  2022  11278  10950
# 31013  A                       Utilities  BA_BA  US  2023    547    639
# 31016  A                 Wholesale Trade  BA_BA  US  2023  10061  10360
# 31018  A  Transportation and Warehousing  BA_BA  US  2023  33486  34192
# 31020  A           Finance and Insurance  BA_BA  US  2023  17538  18728
# 31021  A                     Real Estate  BA_BA  US  2023  23655  24309
# 31065  A          Arts and Entertainment  BA_BA  US  2023  13708  13559
# 32228  A                       Utilities  BA_BA  US  2024    648    647
# 32231  A                 Wholesale Trade  BA_BA  US  2024   9583   9620
# 32233  A  Transportation and Warehousing  BA_BA  US  2024  30697  30776
# 32235  A           Finance and Insurance  BA_BA  US  2024  17577  17452
# 32236  A                     Real Estate  BA_BA  US  2024  21846  21895
# 32261  A          Arts and Entertainment  BA_BA  US  2024  13034  12758
#
#          mar    apr    may    jun    jul    aug    sep    oct    nov    dec
# 28581    487    430    420    368    455    367    411    365    440    338
# 28584  11963  13035  12474  11248  11012  10607  10215  10007   9666   9415
# 28586  36966  42856  43433  41786  40964  39886  40818  40841  41095  38939
# 28588  21374  21875  22405  20590  20358  19738  19936  20810  20970  20189
# 28589  22802  23917  24915  23576  23719  23964  24152  25456  25547  24543
# 28633  12006  14171  14580  13016  12844  11473  11639  11439  11511  11376
# 29798    540    454    459    464    454    510    564    525    477    398
# 29801   9154  10098   9807   9122   9557   9406   9748  10173  10180  10069
# 29803  35561  36778  36185  34306  34035  35668  35540  36615  34132  33364
# 29805  19009  19344  19572  18480  18891  18368  18235  17951  17189  17148
# 29806  24341  24728  25451  23444  23660  23498  24441  24495  23539  23133
# 29850  11043  11441  11794  11632  12352  12309  12312  13168  13065  13161
# 31013    656    643    540    566    610    623    524    601    608    517
# 31016  10758  10257  10500  11398  10886  10361   9861   9458   9452  10481
# 31018  34857  33959  32234  33963  34292  32735  31411  31237  30775  31051
# 31020  18966  18118  18176  18745  19044  19067  18118  17172  17364  17453
# 31021  24996  24222  24019  25201  25472  25145  23411  22525  22117  21708
# 31065  13613  13356  13292  13390  13389  13565  13349  13000  13180  13237
# 32228    803    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32231   9383    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32233  29336    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32235  17748    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32236  21745    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32261  12582    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN

# %%
num_rows, num_columns = startup_ind_filtered.shape

print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 24
# Number of columns: 17

# %%
# Making a new dataset for each of the 6 industries
# Group the DataFrame by 'naics_sector'
sector_groups = startup_ind_filtered.groupby('sector')

# Create a dictionary to store datasets for each sector
sector_datasets = {}

# Iterate over each sector group
for sector, data in sector_groups:
    # Store the dataset for the current sector in the dictionary
    sector_datasets[sector] = data.copy()

# Now, sector_datasets contains a separate dataset for each industry sector
# You can access each dataset using its corresponding sector name as the key

# %%
# creating the individual datasets
utilities_startup = sector_datasets['Utilities']
fin_startup = sector_datasets['Finance and Insurance']
wholesale_startup = sector_datasets['Wholesale Trade']
transport_startup = sector_datasets['Transportation and Warehousing']
real_estate_startup = sector_datasets['Real Estate']
arts_startup = sector_datasets['Arts and Entertainment']

# %%
utilities_startup
# Out:
#       sa     sector series geo  year  jan  feb  mar  apr  may  jun  jul  aug  \
# 28581  A  Utilities  BA_BA  US  2021  377  393  487  430  420  368  455  367
# 29798  A  Utilities  BA_BA  US  2022  419  470  540  454  459  464  454  510
# 31013  A  Utilities  BA_BA  US  2023  547  639  656  643  540  566  610  623
# 32228  A  Utilities  BA_BA  US  2024  648  647  803  NaN  NaN  NaN  NaN  NaN
#
#        sep  oct  nov  dec
# 28581  411  365  440  338
# 29798  564  525  477  398
# 31013  524  601  608  517
# 32228  NaN  NaN  NaN  NaN

# %%
# Out:
#          date  full_onsite_arts_entertain  full_onsite_education  \
# 0   11/1/2021                        20.9                   64.3
# 1   12/1/2021                        28.6                   61.7
# 2    1/1/2022                        31.4                   61.2
# 3    2/1/2022                        41.0                   61.9
# 4    3/1/2022                        36.6                   64.7
# 5    4/1/2022                        38.7                   64.0
# 6    5/1/2022                        43.6                   58.2
# 7    6/1/2022                        48.8                   55.7
# 8    7/1/2022                        43.3                   53.3
# 9    8/1/2022                        42.6                   57.5
# 10   9/1/2022                        46.6                   59.2
# 11  10/1/2022                        49.5                   63.1
# 12  11/1/2022                        50.9                   65.4
# 13  12/1/2022                        51.2                   66.9
# 14   1/1/2023                        51.2                   68.1
# 15   2/1/2023                        45.2                   67.2
# 16   3/1/2023                        41.7                   66.2
# 17   4/1/2023                        48.8                   65.7
# 18   5/1/2023                        49.2                   64.6
# 19   6/1/2023                        45.7                   62.3
# 20   7/1/2023                        36.0                   59.9
# 21   8/1/2023                        33.0                   59.2
# 22   9/1/2023                         NaN                    NaN
# 23  10/1/2023                        31.7                   59.2
# 24  11/1/2023                        33.5                   60.6
# 25  12/1/2023                        39.0                   62.3
# 26   1/1/2024                        40.7                   69.0
# 27   2/1/2024                        41.7                   70.2
# 28   3/1/2024                        38.3                   73.4
#
#     full_onsite_finance_insurance  full_onsite_government  \
# 0                            20.5                    64.5
# 1                            22.9                    64.0
# 2                            25.7                    62.2
# 3                            28.7                    61.0
# 4                            29.2                    62.4
# 5                            28.0                    65.1
# 6                            27.9                    61.0
# 7                            28.1                    58.5
# 8                            29.5                    53.4
# 9                            30.8                    58.7
# 10                           31.2                    57.1
# 11                           32.1                    60.7
# 12                           31.9                    59.2
# 13                           34.4                    62.0
# 14                           35.4                    62.2
# 15                           33.9                    61.3
# 16                           31.3                    60.1
# 17                           29.6                    58.0
# 18                           30.1                    61.3
# 19                           32.4                    61.4
# 20                           30.7                    64.9
# 21                           31.6                    66.9
# 22                            NaN                     NaN
# 23                           28.2                    73.5
# 24                           28.8                    69.2
# 25                           28.8                    67.0
# 26                           29.2                    61.0
# 27                           32.5                    60.7
# 28                           32.7                    57.6
#
#     full_onsite_healthcare  full_onsite_hospitaility_food  \
# 0                     53.3                           73.8
# 1                     55.8                           77.1
# 2                     57.0                           78.6
# 3                     60.9                           79.8
# 4                     60.6                           79.2
# 5                     60.5                           79.6
# 6                     57.9                           80.3
# 7                     58.1                           79.0
# 8                     58.0                           78.5
# 9                     57.5                           82.2
# 10                    58.1                           83.1
# 11                    59.6                           81.4
# 12                    58.6                           77.6
# 13                    57.6                           77.5
# 14                    57.5                           78.1
# 15                    58.6                           82.1
# 16                    58.2                           81.7
# 17                    57.3                           82.1
# 18                    58.1                           81.3
# 19                    59.6                           81.1
# 20                    60.3                           80.9
# 21                    60.9                           78.6
# 22                     NaN                            NaN
# 23                    61.4                           77.8
# 24                    61.9                           76.1
# 25                    61.2                           74.5
# 26                    60.8                           76.5
# 27                    61.6                           78.4
# 28                    63.4                           81.7
#
#     full_onsite_information  full_onsite_manufacturing  \
# 0                      33.8                       66.2
# 1                      31.4                       67.7
# 2                      29.5                       71.2
# 3                      24.1                       72.8
# 4                      22.2                       74.5
# 5                      20.3                       73.6
# 6                      22.6                       73.2
# 7                      24.1                       70.1
# 8                      23.5                       70.1
# 9                      23.1                       67.6
# 10                     23.2                       67.6
# 11                     23.2                       65.9
# 12                     23.4                       68.5
# 13                     23.3                       71.3
# 14                     21.9                       72.2
# 15                     22.4                       70.6
# 16                     23.3                       69.3
# 17                     25.4                       68.5
# 18                     26.3                       67.2
# 19                     24.4                       68.1
# 20                     26.6                       67.9
# 21                     24.3                       72.3
# 22                      NaN                        NaN
# 23                     23.8                       69.7
# 24                     24.7                       69.2
# 25                     26.7                       67.5
# 26                     29.2                       71.4
# 27                     28.5                       73.8
# 28                     29.3                       75.4
#
#     full_onsite_prof_bus_services  ...  full_remote_manufacturing  \
# 0                            35.6  ...                        6.2
# 1                            34.5  ...                        7.6
# 2                            34.2  ...                        8.1
# 3                            33.5  ...                        9.2
# 4                            37.6  ...                        8.4
# 5                            39.2  ...                        6.9
# 6                            38.3  ...                        6.4
# 7                            37.6  ...                        6.5
# 8                            39.7  ...                        7.7
# 9                            41.6  ...                        9.6
# 10                           40.7  ...                       10.1
# 11                           42.6  ...                       10.6
# 12                           43.3  ...                        8.2
# 13                           44.4  ...                        6.4
# 14                           43.2  ...                        5.3
# 15                           40.9  ...                        5.3
# 16                           39.4  ...                        6.1
# 17                           39.7  ...                        5.6
# 18                           41.9  ...                        5.8
# 19                           40.5  ...                        5.8
# 20                           39.6  ...                        6.3
# 21                           38.0  ...                        6.2
# 22                            NaN  ...                        NaN
# 23                           40.1  ...                        6.4
# 24                           39.4  ...                        6.5
# 25                           38.7  ...                        6.5
# 26                           38.7  ...                        5.5
# 27                           38.5  ...                        5.6
# 28                           38.0  ...                        5.5
#
#     full_remote_prof_bus_services  full_remote_realestate  full_remote_retail  \
# 0                            27.2                    22.1                12.0
# 1                            30.8                    21.3                11.5
# 2                            35.4                    22.5                 9.3
# 3                            36.8                    22.1                 9.7
# 4                            32.4                    21.7                 9.0
# 5                            27.5                    12.9                 9.6
# 6                            24.9                    11.2                 8.6
# 7                            24.5                     8.1                 8.7
# 8                            24.1                    13.7                 8.4
# 9                            24.0                    14.6                 8.2
# 10                           23.7                    14.8                 7.2
# 11                           22.5                     9.9                 6.5
# 12                           20.9                    10.4                 6.8
# 13                           21.0                    13.1                 6.3
# 14                           20.7                    13.0                 6.7
# 15                           23.8                    11.8                 6.7
# 16                           23.1                     7.8                 7.2
# 17                           23.3                     9.9                 7.8
# 18                           19.4                     8.8                 7.2
# 19                           21.8                    10.4                 7.4
# 20                           21.5                    15.1                 7.1
# 21                           23.4                    17.1                 6.8
# 22                            NaN                     NaN                 NaN
# 23                           22.2                    17.0                 7.2
# 24                           24.4                    18.0                 7.1
# 25                           25.3                    13.8                 7.7
# 26                           27.1                    14.6                 8.1
# 27                           27.6                    15.2                 8.1
# 28                           29.3                    20.1                 8.4
#
#     full_remote_transp_warehousing  full_remote_utilities  \
# 0                              9.5                    6.4
# 1                              8.0                   12.5
# 2                              6.9                   14.2
# 3                              7.4                   12.3
# 4                              7.1                    4.9
# 5                              6.2                    7.3
# 6                              5.3                   11.5
# 7                              5.3                   17.4
# 8                              3.9                   20.8
# 9                              4.0                   21.5
# 10                             4.7                   17.8
# 11                             5.3                   12.4
# 12                             5.1                   10.1
# 13                             6.2                   15.4
# 14                             6.6                   16.8
# 15                             5.6                   15.0
# 16                             3.4                    8.0
# 17                             3.0                   11.6
# 18                             4.9                   13.7
# 19                             9.3                   13.8
# 20                            11.2                   13.3
# 21                             9.5                   15.6
# 22                             NaN                    NaN
# 23                             4.7                   21.7
# 24                             2.7                   17.5
# 25                             4.0                   16.5
# 26                             5.8                   13.2
# 27                             6.0                   13.1
# 28                             6.3                   10.2
#
#     full_remote_wholesale                                              Notes  \
# 0                    43.3                                                NaN
# 1                    34.4                                                NaN
# 2                    19.2                                                NaN
# 3                    24.9                                                NaN
# 4                    25.9                                                NaN
# 5                    25.3                                                NaN
# 6                    19.7                                                NaN
# 7                    19.4                                                NaN
# 8                    15.1                                                NaN
# 9                    16.5                                                NaN
# 10                   19.2                                                NaN
# 11                   24.7                                                NaN
# 12                   21.8                                                NaN
# 13                   16.9                                                NaN
# 14                   13.6                                                NaN
# 15                   16.1                                                NaN
# 16                   14.4                                                NaN
# 17                   12.3                                                NaN
# 18                   10.4                                                NaN
# 19                   14.4                                                NaN
# 20                   12.2                                                NaN
# 21                   13.4                                                NaN
# 22                    NaN  We suppress estimates for September 2023 due t...
# 23                   12.5                                                NaN
# 24                   20.2                                                NaN
# 25                   21.2                                                NaN
# 26                   19.4                                                NaN
# 27                   14.6                                                NaN
# 28                   10.1                                                NaN
#
#                                               License  \
# 0   Copyright 2024 by Jose Maria Barrero, Nicholas...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                              Citation
# 0    When using this work, please cite: Barrero, J...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
# [29 rows x 46 columns]

# %%
# load in WFH percentages by industry
wfh_ind = pd.read_csv('Work From Home Data/Industry_WFH/WFH_Industry_updated.csv')

# %%
wfh_ind.shape
# Out:
# (56, 14)

# %%
# narrowing down to our desired industries
# List of rows headers to keep
rows_to_keep = ['full_remote_utilities', 'full_remote_finance_insurance',
                   'full_remote_wholesale', 'full_remote_transp_warehousing',
                   'full_remote_realestate', 'full_remote_arts_entertain']

# Select only the desired columns from the dataset
wfh_ind_filtered = wfh_ind[wfh_ind['sector'].isin(rows_to_keep)]

wfh_ind_filtered
# Out:
#                             sector  year   jan   feb   mar   apr   may   jun  \
# 0       full_remote_arts_entertain  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 1       full_remote_arts_entertain  2022  24.3  23.7  23.3  23.5  19.3  18.2
# 2       full_remote_arts_entertain  2023  14.4  19.6  14.5  12.7  13.7  14.5
# 3       full_remote_arts_entertain  2024  14.9  15.5  15.6   NaN   NaN   NaN
# 8    full_remote_finance_insurance  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 9    full_remote_finance_insurance  2022  29.7  28.7  25.1  23.9  21.5  20.5
# 10   full_remote_finance_insurance  2023  22.8  22.0  18.8  19.9  21.6  23.3
# 11   full_remote_finance_insurance  2024  22.5  21.9  23.3   NaN   NaN   NaN
# 36          full_remote_realestate  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 37          full_remote_realestate  2022  22.5  22.1  21.7  12.9  11.2   8.1
# 38          full_remote_realestate  2023  13.0  11.8   7.8   9.9   8.8  10.4
# 39          full_remote_realestate  2024  14.6  15.2  20.1   NaN   NaN   NaN
# 44  full_remote_transp_warehousing  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 45  full_remote_transp_warehousing  2022   6.9   7.4   7.1   6.2   5.3   5.3
# 46  full_remote_transp_warehousing  2023   6.6   5.6   3.4   3.0   4.9   9.3
# 47  full_remote_transp_warehousing  2024   5.8   6.0   6.3   NaN   NaN   NaN
# 48           full_remote_utilities  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 49           full_remote_utilities  2022  14.2  12.3   4.9   7.3  11.5  17.4
# 50           full_remote_utilities  2023  16.8  15.0   8.0  11.6  13.7  13.8
# 51           full_remote_utilities  2024  13.2  13.1  10.2   NaN   NaN   NaN
# 52           full_remote_wholesale  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 53           full_remote_wholesale  2022  19.2  24.9  25.9  25.3  19.7  19.4
# 54           full_remote_wholesale  2023  13.6  16.1  14.4  12.3  10.4  14.4
# 55           full_remote_wholesale  2024  19.4  14.6  10.1   NaN   NaN   NaN
#
#      jul   aug  sept   oct   nov   dec
# 0    NaN   NaN   NaN   NaN  26.4  25.0
# 1   21.8  20.2  20.1  18.2  15.1  16.0
# 2   16.5  13.4   NaN  15.0  14.0  14.6
# 3    NaN   NaN   NaN   NaN   NaN   NaN
# 8    NaN   NaN   NaN   NaN  26.9  29.2
# 9   18.9  19.3  20.7  21.1  23.2  24.4
# 10  21.6  20.9   NaN  20.9  23.5  22.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN
# 36   NaN   NaN   NaN   NaN  22.1  21.3
# 37  13.7  14.6  14.8   9.9  10.4  13.1
# 38  15.1  17.1   NaN  17.0  18.0  13.8
# 39   NaN   NaN   NaN   NaN   NaN   NaN
# 44   NaN   NaN   NaN   NaN   9.5   8.0
# 45   3.9   4.0   4.7   5.3   5.1   6.2
# 46  11.2   9.5   NaN   4.7   2.7   4.0
# 47   NaN   NaN   NaN   NaN   NaN   NaN
# 48   NaN   NaN   NaN   NaN   6.4  12.5
# 49  20.8  21.5  17.8  12.4  10.1  15.4
# 50  13.3  15.6   NaN  21.7  17.5  16.5
# 51   NaN   NaN   NaN   NaN   NaN   NaN
# 52   NaN   NaN   NaN   NaN  43.3  34.4
# 53  15.1  16.5  19.2  24.7  21.8  16.9
# 54  12.2  13.4   NaN  12.5  20.2  21.2
# 55   NaN   NaN   NaN   NaN   NaN   NaN

# %%
# Define the mapping of old values to new values
sector_mapping = {
    'full_remote_utilities': 'Utilities',
    'full_remote_finance_insurance': 'Finance and Insurance',
    'full_remote_wholesale': 'Wholesale Trade',
    'full_remote_transp_warehousing': 'Transportation and Warehousing',
    'full_remote_realestate': 'Real Estate',
    'full_remote_arts_entertain': 'Arts and Entertainment'
}

# Replace the values in the "sector" column using the mapping
wfh_ind_filtered['sector'] = wfh_ind_filtered['sector'].replace(sector_mapping)
# Out:
# C:\Users\keith\AppData\Local\Temp\ipykernel_41144\2422546843.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wfh_ind_filtered['sector'] = wfh_ind_filtered['sector'].replace(sector_mapping)

# %%
wfh_ind_filtered
# Out:
#                             sector  year   jan   feb   mar   apr   may   jun  \
# 0           Arts and Entertainment  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 1           Arts and Entertainment  2022  24.3  23.7  23.3  23.5  19.3  18.2
# 2           Arts and Entertainment  2023  14.4  19.6  14.5  12.7  13.7  14.5
# 3           Arts and Entertainment  2024  14.9  15.5  15.6   NaN   NaN   NaN
# 8            Finance and Insurance  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 9            Finance and Insurance  2022  29.7  28.7  25.1  23.9  21.5  20.5
# 10           Finance and Insurance  2023  22.8  22.0  18.8  19.9  21.6  23.3
# 11           Finance and Insurance  2024  22.5  21.9  23.3   NaN   NaN   NaN
# 36                     Real Estate  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 37                     Real Estate  2022  22.5  22.1  21.7  12.9  11.2   8.1
# 38                     Real Estate  2023  13.0  11.8   7.8   9.9   8.8  10.4
# 39                     Real Estate  2024  14.6  15.2  20.1   NaN   NaN   NaN
# 44  Transportation and Warehousing  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 45  Transportation and Warehousing  2022   6.9   7.4   7.1   6.2   5.3   5.3
# 46  Transportation and Warehousing  2023   6.6   5.6   3.4   3.0   4.9   9.3
# 47  Transportation and Warehousing  2024   5.8   6.0   6.3   NaN   NaN   NaN
# 48                       Utilities  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 49                       Utilities  2022  14.2  12.3   4.9   7.3  11.5  17.4
# 50                       Utilities  2023  16.8  15.0   8.0  11.6  13.7  13.8
# 51                       Utilities  2024  13.2  13.1  10.2   NaN   NaN   NaN
# 52                 Wholesale Trade  2021   NaN   NaN   NaN   NaN   NaN   NaN
# 53                 Wholesale Trade  2022  19.2  24.9  25.9  25.3  19.7  19.4
# 54                 Wholesale Trade  2023  13.6  16.1  14.4  12.3  10.4  14.4
# 55                 Wholesale Trade  2024  19.4  14.6  10.1   NaN   NaN   NaN
#
#      jul   aug  sept   oct   nov   dec
# 0    NaN   NaN   NaN   NaN  26.4  25.0
# 1   21.8  20.2  20.1  18.2  15.1  16.0
# 2   16.5  13.4   NaN  15.0  14.0  14.6
# 3    NaN   NaN   NaN   NaN   NaN   NaN
# 8    NaN   NaN   NaN   NaN  26.9  29.2
# 9   18.9  19.3  20.7  21.1  23.2  24.4
# 10  21.6  20.9   NaN  20.9  23.5  22.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN
# 36   NaN   NaN   NaN   NaN  22.1  21.3
# 37  13.7  14.6  14.8   9.9  10.4  13.1
# 38  15.1  17.1   NaN  17.0  18.0  13.8
# 39   NaN   NaN   NaN   NaN   NaN   NaN
# 44   NaN   NaN   NaN   NaN   9.5   8.0
# 45   3.9   4.0   4.7   5.3   5.1   6.2
# 46  11.2   9.5   NaN   4.7   2.7   4.0
# 47   NaN   NaN   NaN   NaN   NaN   NaN
# 48   NaN   NaN   NaN   NaN   6.4  12.5
# 49  20.8  21.5  17.8  12.4  10.1  15.4
# 50  13.3  15.6   NaN  21.7  17.5  16.5
# 51   NaN   NaN   NaN   NaN   NaN   NaN
# 52   NaN   NaN   NaN   NaN  43.3  34.4
# 53  15.1  16.5  19.2  24.7  21.8  16.9
# 54  12.2  13.4   NaN  12.5  20.2  21.2
# 55   NaN   NaN   NaN   NaN   NaN   NaN

# %%
wfh_ind_filtered.shape
# Out:
# (24, 14)

# %%
# making individual datasets
# Creating a dictionary to store datasets for each sector
sector_datasets = {}

# List of unique sectors
unique_sectors = wfh_ind_filtered['sector'].unique()

# Iterating over each unique sector and creating a dataset for it
for sector in unique_sectors:
    sector_datasets[sector] = wfh_ind_filtered[wfh_ind_filtered['sector'] == sector].copy()

# Now sector_datasets dictionary contains separate datasets for each sector
# You can access them using sector names as keys, for example:
# sector_datasets['full_remote_utilities'], sector_datasets['full_remote_finance_insurance'], etc.

# %%
# making the 6 datasets

utilities_wfh = sector_datasets['Utilities']
fin_wfh = sector_datasets['Finance and Insurance']
wholesale_wfh = sector_datasets['Wholesale Trade']
transport_wfh = sector_datasets['Transportation and Warehousing']
real_estate_wfh = sector_datasets['Real Estate']
arts_wfh = sector_datasets['Arts and Entertainment']

# %%
utilities_wfh
# Out:
#        sector  year   jan   feb   mar   apr   may   jun   jul   aug  sept  \
# 48  Utilities  2021   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 49  Utilities  2022  14.2  12.3   4.9   7.3  11.5  17.4  20.8  21.5  17.8
# 50  Utilities  2023  16.8  15.0   8.0  11.6  13.7  13.8  13.3  15.6   NaN
# 51  Utilities  2024  13.2  13.1  10.2   NaN   NaN   NaN   NaN   NaN   NaN
#
#      oct   nov   dec
# 48   NaN   6.4  12.5
# 49  12.4  10.1  15.4
# 50  21.7  17.5  16.5
# 51   NaN   NaN   NaN

# %%
# find a way to merge the industry datasets 
utilities_startup
# Out:
#       sa     sector series geo  year  jan  feb  mar  apr  may  jun  jul  aug  \
# 28581  A  Utilities  BA_BA  US  2021  377  393  487  430  420  368  455  367
# 29798  A  Utilities  BA_BA  US  2022  419  470  540  454  459  464  454  510
# 31013  A  Utilities  BA_BA  US  2023  547  639  656  643  540  566  610  623
# 32228  A  Utilities  BA_BA  US  2024  648  647  803  NaN  NaN  NaN  NaN  NaN
#
#        sep  oct  nov  dec
# 28581  411  365  440  338
# 29798  564  525  477  398
# 31013  524  601  608  517
# 32228  NaN  NaN  NaN  NaN

# %%
# merge the datasets
utilities = pd.merge(utilities_wfh, utilities_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))
fin_ins = pd.merge(fin_wfh, fin_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))
wholesale_data = pd.merge(wholesale_wfh, wholesale_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))
transport_data = pd.merge(transport_wfh, transport_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))
real_estate_data = pd.merge(real_estate_wfh, real_estate_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))
arts_data = pd.merge(arts_wfh, arts_startup, on=['sector', 'year'], how='inner', suffixes=('_wfh%', '_quantity'))

# %%
'''
# make a graph to show the relationship for each industries
import matplotlib.pyplot as plt

# Assuming merged_data is your DataFrame containing the merged datasets

# Set up the figure and axes
fig, ax1 = plt.subplots()

# Plot the first measurement (percentage from wfh)
utilities.plot(x='year', y=['jan_wfh%', 'feb_wfh%', 'mar_wfh%', 'apr_wfh%', 'may_wfh%', 'jun_wfh%', 'jul_wfh%', 'aug_wfh%', 'sep_wfh%', 'oct_wfh%', 'nov_wfh%', 'dec_wfh%'], ax=ax1, color='blue', marker='o', linestyle='-')

# Create a second y-axis sharing the same x-axis
ax2 = ax1.twinx()

# Plot the second measurement (quantity)
utilities.plot(x='year', y=['jan_quantity', 'feb_quantity', 'mar_quantity', 'apr_quantity', 'may_quantity', 'jun_quantity', 'jul_quantity', 'aug_quantity', 'sep_quantity', 'oct_quantity', 'nov_quantity', 'dec_quantity'], ax=ax2, color='red', marker='s', linestyle='-')

# Set labels and title
ax1.set_xlabel('Year')
ax1.set_ylabel('Percentage of WFH', color='blue')
ax2.set_ylabel('Quantity of Startups', color='red')
plt.title('Comparison of Percentage of WFH and Quantity of Startups Developed Over Years')

# Show the plot
plt.show()'''
# Out:
# "\n# make a graph to show the relationship for each industries\nimport matplotlib.pyplot as plt\n\n# Assuming merged_data is your DataFrame containing the merged datasets\n\n# Set up the figure and axes\nfig, ax1 = plt.subplots()\n\n# Plot the first measurement (percentage from wfh)\nutilities.plot(x='year', y=['jan_wfh%', 'feb_wfh%', 'mar_wfh%', 'apr_wfh%', 'may_wfh%', 'jun_wfh%', 'jul_wfh%', 'aug_wfh%', 'sep_wfh%', 'oct_wfh%', 'nov_wfh%', 'dec_wfh%'], ax=ax1, color='blue', marker='o', linestyle='-')\n\n# Create a second y-axis sharing the same x-axis\nax2 = ax1.twinx()\n\n# Plot the second measurement (quantity)\nutilities.plot(x='year', y=['jan_quantity', 'feb_quantity', 'mar_quantity', 'apr_quantity', 'may_quantity', 'jun_quantity', 'jul_quantity', 'aug_quantity', 'sep_quantity', 'oct_quantity', 'nov_quantity', 'dec_quantity'], ax=ax2, color='red', marker='s', linestyle='-')\n\n# Set labels and title\nax1.set_xlabel('Year')\nax1.set_ylabel('Percentage of WFH', color='blue')\nax2.set_ylabel('Quantity of Startups', color='red')\nplt.title('Comparison of Percentage of WFH and Quantity of Startups Developed Over Years')\n\n# Show the plot\nplt.show()"

# %%
startup_fixed = pd.read_csv('Startup Data/Industry/startup_fix.csv')
wfh_fixed = pd.read_csv('Work From Home Data/Industry_WFH/wfh_fix.csv')
startup_fixed
# Out:
#     sa                  sector series geo       year  startups
# 0    A               Utilities  BA_BA  US   1/1/2021       377
# 1    A               Utilities  BA_BA  US   2/1/2021       393
# 2    A               Utilities  BA_BA  US   3/1/2021       487
# 3    A               Utilities  BA_BA  US   4/1/2021       430
# 4    A               Utilities  BA_BA  US   5/1/2021       420
# ..  ..                     ...    ...  ..        ...       ...
# 229  A  Arts and Entertainment  BA_BA  US  11/1/2023     13180
# 230  A  Arts and Entertainment  BA_BA  US  12/1/2023     13237
# 231  A  Arts and Entertainment  BA_BA  US   1/1/2024     13034
# 232  A  Arts and Entertainment  BA_BA  US   2/1/2024     12758
# 233  A  Arts and Entertainment  BA_BA  US   3/1/2024     12582
#
# [234 rows x 6 columns]

# %%
wfh_fixed
# Out:
#                      sector       year  wfh%
# 0    Arts and Entertainment  11/1/2021  26.4
# 1    Arts and Entertainment  12/1/2021  25.0
# 2    Arts and Entertainment   1/1/2022  24.3
# 3    Arts and Entertainment   2/1/2022  23.7
# 4    Arts and Entertainment   3/1/2022  23.3
# ..                      ...        ...   ...
# 169         Wholesale Trade  11/1/2023  20.2
# 170         Wholesale Trade  12/1/2023  21.2
# 171         Wholesale Trade   1/1/2024  19.4
# 172         Wholesale Trade   2/1/2024  14.6
# 173         Wholesale Trade   3/1/2024  10.1
#
# [174 rows x 3 columns]

# %%
startup_fixed['year'] = pd.to_datetime(startup_fixed['year'])
startup_fixed['year'] = startup_fixed['year'].dt.strftime('%m/%Y')
startup_fixed = startup_fixed.drop(columns = ['series', 'geo', 'sa'])
startup_fixed
# Out:
#                      sector     year  startups
# 0                 Utilities  01/2021       377
# 1                 Utilities  02/2021       393
# 2                 Utilities  03/2021       487
# 3                 Utilities  04/2021       430
# 4                 Utilities  05/2021       420
# ..                      ...      ...       ...
# 229  Arts and Entertainment  11/2023     13180
# 230  Arts and Entertainment  12/2023     13237
# 231  Arts and Entertainment  01/2024     13034
# 232  Arts and Entertainment  02/2024     12758
# 233  Arts and Entertainment  03/2024     12582
#
# [234 rows x 3 columns]

# %%
wfh_fixed['year'] = pd.to_datetime(wfh_fixed['year'])
wfh_fixed['year'] = wfh_fixed['year'].dt.strftime('%m/%Y')
wfh_fixed
# Out:
#                      sector     year  wfh%
# 0    Arts and Entertainment  11/2021  26.4
# 1    Arts and Entertainment  12/2021  25.0
# 2    Arts and Entertainment  01/2022  24.3
# 3    Arts and Entertainment  02/2022  23.7
# 4    Arts and Entertainment  03/2022  23.3
# ..                      ...      ...   ...
# 169         Wholesale Trade  11/2023  20.2
# 170         Wholesale Trade  12/2023  21.2
# 171         Wholesale Trade  01/2024  19.4
# 172         Wholesale Trade  02/2024  14.6
# 173         Wholesale Trade  03/2024  10.1
#
# [174 rows x 3 columns]

# %%
merged = pd.merge(wfh_fixed, startup_fixed, on=['sector', 'year'], how='inner', validate = 'one_to_one')
merged
# Out:
#                      sector     year  wfh%  startups
# 0    Arts and Entertainment  11/2021  26.4     11511
# 1    Arts and Entertainment  12/2021  25.0     11376
# 2    Arts and Entertainment  01/2022  24.3     11278
# 3    Arts and Entertainment  02/2022  23.7     10950
# 4    Arts and Entertainment  03/2022  23.3     11043
# ..                      ...      ...   ...       ...
# 169         Wholesale Trade  11/2023  20.2      9452
# 170         Wholesale Trade  12/2023  21.2     10481
# 171         Wholesale Trade  01/2024  19.4      9583
# 172         Wholesale Trade  02/2024  14.6      9620
# 173         Wholesale Trade  03/2024  10.1      9383
#
# [174 rows x 4 columns]

# %%
pd.set_option('display.max_rows', None)
merged = merged.dropna()
merged = merged.rename(columns={'wfh%' : 'wfh'})
merged
# Out:
#                              sector     year   wfh  startups
# 0            Arts and Entertainment  11/2021  26.4     11511
# 1            Arts and Entertainment  12/2021  25.0     11376
# 2            Arts and Entertainment  01/2022  24.3     11278
# 3            Arts and Entertainment  02/2022  23.7     10950
# 4            Arts and Entertainment  03/2022  23.3     11043
# 5            Arts and Entertainment  04/2022  23.5     11441
# 6            Arts and Entertainment  05/2022  19.3     11794
# 7            Arts and Entertainment  06/2022  18.2     11632
# 8            Arts and Entertainment  07/2022  21.8     12352
# 9            Arts and Entertainment  08/2022  20.2     12309
# 10           Arts and Entertainment  09/2022  20.1     12312
# 11           Arts and Entertainment  10/2022  18.2     13168
# 12           Arts and Entertainment  11/2022  15.1     13065
# 13           Arts and Entertainment  12/2022  16.0     13161
# 14           Arts and Entertainment  01/2023  14.4     13708
# 15           Arts and Entertainment  02/2023  19.6     13559
# 16           Arts and Entertainment  03/2023  14.5     13613
# 17           Arts and Entertainment  04/2023  12.7     13356
# 18           Arts and Entertainment  05/2023  13.7     13292
# 19           Arts and Entertainment  06/2023  14.5     13390
# 20           Arts and Entertainment  07/2023  16.5     13389
# 21           Arts and Entertainment  08/2023  13.4     13565
# 23           Arts and Entertainment  10/2023  15.0     13000
# 24           Arts and Entertainment  11/2023  14.0     13180
# 25           Arts and Entertainment  12/2023  14.6     13237
# 26           Arts and Entertainment  01/2024  14.9     13034
# 27           Arts and Entertainment  02/2024  15.5     12758
# 28           Arts and Entertainment  03/2024  15.6     12582
# 29            Finance and Insurance  11/2021  26.9     20970
# 30            Finance and Insurance  12/2021  29.2     20189
# 31            Finance and Insurance  01/2022  29.7     20186
# 32            Finance and Insurance  02/2022  28.7     19529
# 33            Finance and Insurance  03/2022  25.1     19009
# 34            Finance and Insurance  04/2022  23.9     19344
# 35            Finance and Insurance  05/2022  21.5     19572
# 36            Finance and Insurance  06/2022  20.5     18480
# 37            Finance and Insurance  07/2022  18.9     18891
# 38            Finance and Insurance  08/2022  19.3     18368
# 39            Finance and Insurance  09/2022  20.7     18235
# 40            Finance and Insurance  10/2022  21.1     17951
# 41            Finance and Insurance  11/2022  23.2     17189
# 42            Finance and Insurance  12/2022  24.4     17148
# 43            Finance and Insurance  01/2023  22.8     17538
# 44            Finance and Insurance  02/2023  22.0     18728
# 45            Finance and Insurance  03/2023  18.8     18966
# 46            Finance and Insurance  04/2023  19.9     18118
# 47            Finance and Insurance  05/2023  21.6     18176
# 48            Finance and Insurance  06/2023  23.3     18745
# 49            Finance and Insurance  07/2023  21.6     19044
# 50            Finance and Insurance  08/2023  20.9     19067
# 52            Finance and Insurance  10/2023  20.9     17172
# 53            Finance and Insurance  11/2023  23.5     17364
# 54            Finance and Insurance  12/2023  22.0     17453
# 55            Finance and Insurance  01/2024  22.5     17577
# 56            Finance and Insurance  02/2024  21.9     17452
# 57            Finance and Insurance  03/2024  23.3     17748
# 58                      Real Estate  11/2021  22.1     25547
# 59                      Real Estate  12/2021  21.3     24543
# 60                      Real Estate  01/2022  22.5     25218
# 61                      Real Estate  02/2022  22.1     24449
# 62                      Real Estate  03/2022  21.7     24341
# 63                      Real Estate  04/2022  12.9     24728
# 64                      Real Estate  05/2022  11.2     25451
# 65                      Real Estate  06/2022   8.1     23444
# 66                      Real Estate  07/2022  13.7     23660
# 67                      Real Estate  08/2022  14.6     23498
# 68                      Real Estate  09/2022  14.8     24441
# 69                      Real Estate  10/2022   9.9     24495
# 70                      Real Estate  11/2022  10.4     23539
# 71                      Real Estate  12/2022  13.1     23133
# 72                      Real Estate  01/2023  13.0     23655
# 73                      Real Estate  02/2023  11.8     24309
# 74                      Real Estate  03/2023   7.8     24996
# 75                      Real Estate  04/2023   9.9     24222
# 76                      Real Estate  05/2023   8.8     24019
# 77                      Real Estate  06/2023  10.4     25201
# 78                      Real Estate  07/2023  15.1     25472
# 79                      Real Estate  08/2023  17.1     25145
# 81                      Real Estate  10/2023  17.0     22525
# 82                      Real Estate  11/2023  18.0     22117
# 83                      Real Estate  12/2023  13.8     21708
# 84                      Real Estate  01/2024  14.6     21846
# 85                      Real Estate  02/2024  15.2     21895
# 86                      Real Estate  03/2024  20.1     21745
# 87   Transportation and Warehousing  11/2021   9.5     41095
# 88   Transportation and Warehousing  12/2021   8.0     38939
# 89   Transportation and Warehousing  01/2022   6.9     38625
# 90   Transportation and Warehousing  02/2022   7.4     37345
# 91   Transportation and Warehousing  03/2022   7.1     35561
# 92   Transportation and Warehousing  04/2022   6.2     36778
# 93   Transportation and Warehousing  05/2022   5.3     36185
# 94   Transportation and Warehousing  06/2022   5.3     34306
# 95   Transportation and Warehousing  07/2022   3.9     34035
# 96   Transportation and Warehousing  08/2022   4.0     35668
# 97   Transportation and Warehousing  09/2022   4.7     35540
# 98   Transportation and Warehousing  10/2022   5.3     36615
# 99   Transportation and Warehousing  11/2022   5.1     34132
# 100  Transportation and Warehousing  12/2022   6.2     33364
# 101  Transportation and Warehousing  01/2023   6.6     33486
# 102  Transportation and Warehousing  02/2023   5.6     34192
# 103  Transportation and Warehousing  03/2023   3.4     34857
# 104  Transportation and Warehousing  04/2023   3.0     33959
# 105  Transportation and Warehousing  05/2023   4.9     32234
# 106  Transportation and Warehousing  06/2023   9.3     33963
# 107  Transportation and Warehousing  07/2023  11.2     34292
# 108  Transportation and Warehousing  08/2023   9.5     32735
# 110  Transportation and Warehousing  10/2023   4.7     31237
# 111  Transportation and Warehousing  11/2023   2.7     30775
# 112  Transportation and Warehousing  12/2023   4.0     31051
# 113  Transportation and Warehousing  01/2024   5.8     30697
# 114  Transportation and Warehousing  02/2024   6.0     30776
# 115  Transportation and Warehousing  03/2024   6.3     29336
# 116                       Utilities  11/2021   6.4       440
# 117                       Utilities  12/2021  12.5       338
# 118                       Utilities  01/2022  14.2       419
# 119                       Utilities  02/2022  12.3       470
# 120                       Utilities  03/2022   4.9       540
# 121                       Utilities  04/2022   7.3       454
# 122                       Utilities  05/2022  11.5       459
# 123                       Utilities  06/2022  17.4       464
# 124                       Utilities  07/2022  20.8       454
# 125                       Utilities  08/2022  21.5       510
# 126                       Utilities  09/2022  17.8       564
# 127                       Utilities  10/2022  12.4       525
# 128                       Utilities  11/2022  10.1       477
# 129                       Utilities  12/2022  15.4       398
# 130                       Utilities  01/2023  16.8       547
# 131                       Utilities  02/2023  15.0       639
# 132                       Utilities  03/2023   8.0       656
# 133                       Utilities  04/2023  11.6       643
# 134                       Utilities  05/2023  13.7       540
# 135                       Utilities  06/2023  13.8       566
# 136                       Utilities  07/2023  13.3       610
# 137                       Utilities  08/2023  15.6       623
# 139                       Utilities  10/2023  21.7       601
# 140                       Utilities  11/2023  17.5       608
# 141                       Utilities  12/2023  16.5       517
# 142                       Utilities  01/2024  13.2       648
# 143                       Utilities  02/2024  13.1       647
# 144                       Utilities  03/2024  10.2       803
# 145                 Wholesale Trade  11/2021  43.3      9666
# 146                 Wholesale Trade  12/2021  34.4      9415
# 147                 Wholesale Trade  01/2022  19.2      9655
# 148                 Wholesale Trade  02/2022  24.9      9273
# 149                 Wholesale Trade  03/2022  25.9      9154
# 150                 Wholesale Trade  04/2022  25.3     10098
# 151                 Wholesale Trade  05/2022  19.7      9807
# 152                 Wholesale Trade  06/2022  19.4      9122
# 153                 Wholesale Trade  07/2022  15.1      9557
# 154                 Wholesale Trade  08/2022  16.5      9406
# 155                 Wholesale Trade  09/2022  19.2      9748
# 156                 Wholesale Trade  10/2022  24.7     10173
# 157                 Wholesale Trade  11/2022  21.8     10180
# 158                 Wholesale Trade  12/2022  16.9     10069
# 159                 Wholesale Trade  01/2023  13.6     10061
# 160                 Wholesale Trade  02/2023  16.1     10360
# 161                 Wholesale Trade  03/2023  14.4     10758
# 162                 Wholesale Trade  04/2023  12.3     10257
# 163                 Wholesale Trade  05/2023  10.4     10500
# 164                 Wholesale Trade  06/2023  14.4     11398
# 165                 Wholesale Trade  07/2023  12.2     10886
# 166                 Wholesale Trade  08/2023  13.4     10361
# 168                 Wholesale Trade  10/2023  12.5      9458
# 169                 Wholesale Trade  11/2023  20.2      9452
# 170                 Wholesale Trade  12/2023  21.2     10481
# 171                 Wholesale Trade  01/2024  19.4      9583
# 172                 Wholesale Trade  02/2024  14.6      9620
# 173                 Wholesale Trade  03/2024  10.1      9383

# %%
# Plot each year's time series in its own facet
g = sns.relplot(
    data=merged,
    x="year", y="startups", col="sector", hue="sector",
    kind="line", palette="crest", linewidth=3, zorder=5,
    col_wrap=3, height=2, aspect=3, legend=False,
)

# Iterate over each subplot to customize further
for sector, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(0.1, .85, sector, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=merged, x="year", y="startups", units="sector",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )


# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[0:36])
ax.set_xticklabels([])


# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("Months", "startups")
g.tight_layout()
g.savefig('images/multiple_time_series.jpg', bbox_inches='tight', dpi=150)

# %%
merged
# Out:
#                              sector     year   wfh  startups
# 0            Arts and Entertainment  11/2021  26.4     11511
# 1            Arts and Entertainment  12/2021  25.0     11376
# 2            Arts and Entertainment  01/2022  24.3     11278
# 3            Arts and Entertainment  02/2022  23.7     10950
# 4            Arts and Entertainment  03/2022  23.3     11043
# 5            Arts and Entertainment  04/2022  23.5     11441
# 6            Arts and Entertainment  05/2022  19.3     11794
# 7            Arts and Entertainment  06/2022  18.2     11632
# 8            Arts and Entertainment  07/2022  21.8     12352
# 9            Arts and Entertainment  08/2022  20.2     12309
# 10           Arts and Entertainment  09/2022  20.1     12312
# 11           Arts and Entertainment  10/2022  18.2     13168
# 12           Arts and Entertainment  11/2022  15.1     13065
# 13           Arts and Entertainment  12/2022  16.0     13161
# 14           Arts and Entertainment  01/2023  14.4     13708
# 15           Arts and Entertainment  02/2023  19.6     13559
# 16           Arts and Entertainment  03/2023  14.5     13613
# 17           Arts and Entertainment  04/2023  12.7     13356
# 18           Arts and Entertainment  05/2023  13.7     13292
# 19           Arts and Entertainment  06/2023  14.5     13390
# 20           Arts and Entertainment  07/2023  16.5     13389
# 21           Arts and Entertainment  08/2023  13.4     13565
# 23           Arts and Entertainment  10/2023  15.0     13000
# 24           Arts and Entertainment  11/2023  14.0     13180
# 25           Arts and Entertainment  12/2023  14.6     13237
# 26           Arts and Entertainment  01/2024  14.9     13034
# 27           Arts and Entertainment  02/2024  15.5     12758
# 28           Arts and Entertainment  03/2024  15.6     12582
# 29            Finance and Insurance  11/2021  26.9     20970
# 30            Finance and Insurance  12/2021  29.2     20189
# 31            Finance and Insurance  01/2022  29.7     20186
# 32            Finance and Insurance  02/2022  28.7     19529
# 33            Finance and Insurance  03/2022  25.1     19009
# 34            Finance and Insurance  04/2022  23.9     19344
# 35            Finance and Insurance  05/2022  21.5     19572
# 36            Finance and Insurance  06/2022  20.5     18480
# 37            Finance and Insurance  07/2022  18.9     18891
# 38            Finance and Insurance  08/2022  19.3     18368
# 39            Finance and Insurance  09/2022  20.7     18235
# 40            Finance and Insurance  10/2022  21.1     17951
# 41            Finance and Insurance  11/2022  23.2     17189
# 42            Finance and Insurance  12/2022  24.4     17148
# 43            Finance and Insurance  01/2023  22.8     17538
# 44            Finance and Insurance  02/2023  22.0     18728
# 45            Finance and Insurance  03/2023  18.8     18966
# 46            Finance and Insurance  04/2023  19.9     18118
# 47            Finance and Insurance  05/2023  21.6     18176
# 48            Finance and Insurance  06/2023  23.3     18745
# 49            Finance and Insurance  07/2023  21.6     19044
# 50            Finance and Insurance  08/2023  20.9     19067
# 52            Finance and Insurance  10/2023  20.9     17172
# 53            Finance and Insurance  11/2023  23.5     17364
# 54            Finance and Insurance  12/2023  22.0     17453
# 55            Finance and Insurance  01/2024  22.5     17577
# 56            Finance and Insurance  02/2024  21.9     17452
# 57            Finance and Insurance  03/2024  23.3     17748
# 58                      Real Estate  11/2021  22.1     25547
# 59                      Real Estate  12/2021  21.3     24543
# 60                      Real Estate  01/2022  22.5     25218
# 61                      Real Estate  02/2022  22.1     24449
# 62                      Real Estate  03/2022  21.7     24341
# 63                      Real Estate  04/2022  12.9     24728
# 64                      Real Estate  05/2022  11.2     25451
# 65                      Real Estate  06/2022   8.1     23444
# 66                      Real Estate  07/2022  13.7     23660
# 67                      Real Estate  08/2022  14.6     23498
# 68                      Real Estate  09/2022  14.8     24441
# 69                      Real Estate  10/2022   9.9     24495
# 70                      Real Estate  11/2022  10.4     23539
# 71                      Real Estate  12/2022  13.1     23133
# 72                      Real Estate  01/2023  13.0     23655
# 73                      Real Estate  02/2023  11.8     24309
# 74                      Real Estate  03/2023   7.8     24996
# 75                      Real Estate  04/2023   9.9     24222
# 76                      Real Estate  05/2023   8.8     24019
# 77                      Real Estate  06/2023  10.4     25201
# 78                      Real Estate  07/2023  15.1     25472
# 79                      Real Estate  08/2023  17.1     25145
# 81                      Real Estate  10/2023  17.0     22525
# 82                      Real Estate  11/2023  18.0     22117
# 83                      Real Estate  12/2023  13.8     21708
# 84                      Real Estate  01/2024  14.6     21846
# 85                      Real Estate  02/2024  15.2     21895
# 86                      Real Estate  03/2024  20.1     21745
# 87   Transportation and Warehousing  11/2021   9.5     41095
# 88   Transportation and Warehousing  12/2021   8.0     38939
# 89   Transportation and Warehousing  01/2022   6.9     38625
# 90   Transportation and Warehousing  02/2022   7.4     37345
# 91   Transportation and Warehousing  03/2022   7.1     35561
# 92   Transportation and Warehousing  04/2022   6.2     36778
# 93   Transportation and Warehousing  05/2022   5.3     36185
# 94   Transportation and Warehousing  06/2022   5.3     34306
# 95   Transportation and Warehousing  07/2022   3.9     34035
# 96   Transportation and Warehousing  08/2022   4.0     35668
# 97   Transportation and Warehousing  09/2022   4.7     35540
# 98   Transportation and Warehousing  10/2022   5.3     36615
# 99   Transportation and Warehousing  11/2022   5.1     34132
# 100  Transportation and Warehousing  12/2022   6.2     33364
# 101  Transportation and Warehousing  01/2023   6.6     33486
# 102  Transportation and Warehousing  02/2023   5.6     34192
# 103  Transportation and Warehousing  03/2023   3.4     34857
# 104  Transportation and Warehousing  04/2023   3.0     33959
# 105  Transportation and Warehousing  05/2023   4.9     32234
# 106  Transportation and Warehousing  06/2023   9.3     33963
# 107  Transportation and Warehousing  07/2023  11.2     34292
# 108  Transportation and Warehousing  08/2023   9.5     32735
# 110  Transportation and Warehousing  10/2023   4.7     31237
# 111  Transportation and Warehousing  11/2023   2.7     30775
# 112  Transportation and Warehousing  12/2023   4.0     31051
# 113  Transportation and Warehousing  01/2024   5.8     30697
# 114  Transportation and Warehousing  02/2024   6.0     30776
# 115  Transportation and Warehousing  03/2024   6.3     29336
# 116                       Utilities  11/2021   6.4       440
# 117                       Utilities  12/2021  12.5       338
# 118                       Utilities  01/2022  14.2       419
# 119                       Utilities  02/2022  12.3       470
# 120                       Utilities  03/2022   4.9       540
# 121                       Utilities  04/2022   7.3       454
# 122                       Utilities  05/2022  11.5       459
# 123                       Utilities  06/2022  17.4       464
# 124                       Utilities  07/2022  20.8       454
# 125                       Utilities  08/2022  21.5       510
# 126                       Utilities  09/2022  17.8       564
# 127                       Utilities  10/2022  12.4       525
# 128                       Utilities  11/2022  10.1       477
# 129                       Utilities  12/2022  15.4       398
# 130                       Utilities  01/2023  16.8       547
# 131                       Utilities  02/2023  15.0       639
# 132                       Utilities  03/2023   8.0       656
# 133                       Utilities  04/2023  11.6       643
# 134                       Utilities  05/2023  13.7       540
# 135                       Utilities  06/2023  13.8       566
# 136                       Utilities  07/2023  13.3       610
# 137                       Utilities  08/2023  15.6       623
# 139                       Utilities  10/2023  21.7       601
# 140                       Utilities  11/2023  17.5       608
# 141                       Utilities  12/2023  16.5       517
# 142                       Utilities  01/2024  13.2       648
# 143                       Utilities  02/2024  13.1       647
# 144                       Utilities  03/2024  10.2       803
# 145                 Wholesale Trade  11/2021  43.3      9666
# 146                 Wholesale Trade  12/2021  34.4      9415
# 147                 Wholesale Trade  01/2022  19.2      9655
# 148                 Wholesale Trade  02/2022  24.9      9273
# 149                 Wholesale Trade  03/2022  25.9      9154
# 150                 Wholesale Trade  04/2022  25.3     10098
# 151                 Wholesale Trade  05/2022  19.7      9807
# 152                 Wholesale Trade  06/2022  19.4      9122
# 153                 Wholesale Trade  07/2022  15.1      9557
# 154                 Wholesale Trade  08/2022  16.5      9406
# 155                 Wholesale Trade  09/2022  19.2      9748
# 156                 Wholesale Trade  10/2022  24.7     10173
# 157                 Wholesale Trade  11/2022  21.8     10180
# 158                 Wholesale Trade  12/2022  16.9     10069
# 159                 Wholesale Trade  01/2023  13.6     10061
# 160                 Wholesale Trade  02/2023  16.1     10360
# 161                 Wholesale Trade  03/2023  14.4     10758
# 162                 Wholesale Trade  04/2023  12.3     10257
# 163                 Wholesale Trade  05/2023  10.4     10500
# 164                 Wholesale Trade  06/2023  14.4     11398
# 165                 Wholesale Trade  07/2023  12.2     10886
# 166                 Wholesale Trade  08/2023  13.4     10361
# 168                 Wholesale Trade  10/2023  12.5      9458
# 169                 Wholesale Trade  11/2023  20.2      9452
# 170                 Wholesale Trade  12/2023  21.2     10481
# 171                 Wholesale Trade  01/2024  19.4      9583
# 172                 Wholesale Trade  02/2024  14.6      9620
# 173                 Wholesale Trade  03/2024  10.1      9383

# %%
# Plot each year's time series in its own facet
g = sns.relplot(
    data=merged,
    x="year", y="wfh", col="sector", hue="sector",
    kind="line", palette="crest", linewidth=3, zorder=5,
    col_wrap=3, height=2, aspect=3, legend=False,
)

# Iterate over each subplot to customize further
for sector, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(0.1, .85, sector, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=merged, x="year", y="wfh", units="sector",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )


# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[0:36])
ax.set_xticklabels([])


# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("Months", "wfh%")
g.tight_layout()
g.savefig('images/wfh_time_series.jpg', bbox_inches='tight', dpi=150)

# %%
sns.scatterplot(data = merged, x = 'wfh', y = 'startups')
# Out:
# <Axes: xlabel='wfh', ylabel='startups'>

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 6))
results = smf.ols('startups ~ wfh', data=merged).fit()
sm.graphics.plot_regress_exog(results, 'wfh', fig=fig)
plt.show()

# %%
reg = sm.graphics.plot_partregress(endog='startups', exog_i='wfh',
                             exog_others=['sector'],
                              data=merged, obs_labels=False) 
plt.show()
reg.savefig('images/regression.jpg', bbox_inches='tight', dpi=150)  # Save each scatterplot with a unique name

# %%
sns.scatterplot(data = merged, x = 'wfh', y = 'startups', hue = 'sector')
# Out:
# <Axes: xlabel='wfh', ylabel='startups'>

# %%
sectors = merged['sector'].unique()

# Create a scatterplot for each sector
for sector in sectors:
    # Filter data for the current sector
    sector_data = merged[merged['sector'] == sector]
    
    # Create scatterplot
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=sector_data, x='wfh', y='startups', hue='sector')
    plt.title(f'Scatterplot for {sector}')
    plt.xlabel('WFH')
    plt.ylabel('Number of Startups')
    plt.legend()
    plt.grid(False)
    plt.tight_layout()
    plt.show()
    plt.savefig('images/'f'scatterplot_{sector}.jpg', bbox_inches='tight', dpi=150)  # Save each scatterplot with a unique name

# %%
j = sns.jointplot(data=merged, x="wfh", y="startups", hue = "sector")
j.savefig('images/multiple_time_series.jpg', bbox_inches='tight', dpi=150)

# %%
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col  # Importing summary_col function
# regression model to show the relationship between the WFH share of the workforce and the number of startups created

# Run OLS
m1 = sm.OLS.from_formula('startups ~ wfh + sector', data=merged).fit()
m2 = sm.OLS.from_formula('startups ~ np.log(wfh) + sector', data=merged).fit()  # Use np.log for log transformation
#m3 = sm.OLS.from_formula('np.log(startups) ~ wfh + sector', data=wfh_startups).fit()  # Log transform dependent variable

# Print out multiple regression results at once
table = summary_col(results=[m1, m2],
                    float_format='%0.2f',
                    stars=True,
                    model_names=['m1', 'm2'],
                    info_dict=None)  # You can pass additional information here if needed

print(table)
# Out:
# ==================================================================
#                                               m1           m2
# ------------------------------------------------------------------
# Intercept                                12790.12***  11924.84***
#                                          (504.09)     (1075.20)
# sector[T.Finance and Insurance]          5946.52***   5838.07***
#                                          (385.21)     (378.70)
# sector[T.Real Estate]                    11262.56***  11350.12***
#                                          (376.20)     (376.54)
# sector[T.Transportation and Warehousing] 21619.40***  22010.57***
#                                          (467.04)     (552.29)
# sector[T.Utilities]                      -12110.60*** -11995.76***
#                                          (381.66)     (383.40)
# sector[T.Wholesale Trade]                -2675.05***  -2688.65***
#                                          (368.40)     (367.42)
# wfh                                      -10.06
#                                          (23.99)
# np.log(wfh)                                           238.72
#                                                       (364.00)
# R-squared                                0.98         0.98
# R-squared Adj.                           0.98         0.98
# ==================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
